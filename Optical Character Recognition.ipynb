# %% [markdown]
# ## Name:- Vitthal Atmaram Dharne.

# %% [markdown]
# ### Task 1 - Character detector which extracts printed or handwritten text from an image or video.

# %% [markdown]
# ### Method Used:- Optical Character Recognition (OCR)

# %% [markdown]
# ###### Step 1:- Install easyocr python Library.

# %%
#!pip install easyocr
#!pip install opencv-python

# %% [markdown]
# ###### Step 2:- Import necessary python Libraries.

# %% [raw]
# import easyocr
# import cv2
# from matplotlib import pyplot as plt
# import numpy as np

# %% [markdown]
# ###### step 3:- Save Location of Test Images with variables.

# %%
PATH = 'C:/Users/HP/Downloads/surf.jpeg'
IMAGE_PATH = 'C:/Users/HP/Downloads/sign.png'

# %% [markdown]
# ###### Step 4:- Make an Object 'Reader' and set default Language as English , Read the Images given using 'Reader' object.

# %%
reader = easyocr.Reader(['en'], gpu=False)
result = reader.readtext(IMAGE_PATH)
result1 = reader.readtext(PATH)
result
result1
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [([[18, 18], [293, 18], [293, 145], [18, 145]], 'SURF', 0.9862082004547119)]

# %%
top_left = tuple(result[0][0][0])
bottom_right = tuple(result[0][0][2])
text = result[0][1]
font = cv2.FONT_HERSHEY_SIMPLEX

# %%
top_left1 = tuple(result1[0][0][0])
bottom_right1 = tuple(result1[0][0][2])
text1 = result1[0][1]
font1 = cv2.FONT_HERSHEY_SIMPLEX

# %% [markdown]
# ###### Step 5:- For single Line Images

# %%
img1 = cv2.imread(PATH)
img1 = cv2.rectangle(img1,top_left1,bottom_right1,(0,255,0),3)
img1 = cv2.putText(img1,text1,top_left1, font1, 0.5,(255,255,255),2,cv2.LINE_AA)
plt.imshow(img1)
plt.show()

# %% [markdown]
# ###### Step 6:- For Multiline Images

# %%
img = cv2.imread(IMAGE_PATH)
spacer = 100
for detection in result: 
    top_left = tuple(detection[0][0])
    bottom_right = tuple(detection[0][2])
    text = detection[1]
    img = cv2.rectangle(img,top_left,bottom_right,(0,255,0),3)
    img = cv2.putText(img,text,(20,spacer), font, 0.5,(0,255,0),2,cv2.LINE_AA)
    spacer+=15
    
plt.imshow(img)
plt.show()
